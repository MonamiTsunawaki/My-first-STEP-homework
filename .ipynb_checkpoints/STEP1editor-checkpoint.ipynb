# %%
def sortbox(given):
    list1 = list(given)
    list1.sort()
    list1 = ''.join(list1)
    return list1

# %%
sortbox('lkjiejfdsgfc')
# Out:
# 'cdeffgijjkls'

# %%
with open('dictionary.words.txt', 'r') as f:
    dic = []
    list_for_search = []
    for word in f:
        word = word.rstrip('\n')
        dic.append(word)
    dic2 = {sortbox(word2.lower()) : word2 for word2 in dic}
    list_for_search = list(dic2.keys())

# %%
dic2
# Out:
# {'alo': 'Ola',
#  'aacehn': 'Aachen',
#  'aaahily': 'Aaliyah',
#  'aanor': 'Aaron',
#  'aabbs': 'Abbas',
#  'aabbdis': 'Abbasid',
#  'abbott': 'Abbott',
#  'abby': 'baby',
#  'abdlu': 'Abdul',
#  'abe': 'Abe',
#  'abel': 'bale',
#  'aabdelr': 'Abelard',
#  'abelnos': 'Abelson',
#  'abdeeenr': 'Aberdeen',
#  'aabehnrty': 'Abernathy',
#  'aabdijn': 'Abidjan',
#  'aabgiil': 'Abigail',
#  'abeeiln': 'Abilene',
#  'abenr': 'Arneb',
#  'aaabhmr': 'Abraham',
#  'aabmr': 'Abram',
#  'aabmrs': 'Abrams',
#  'aablmos': 'Absalom',
#  'aabju': 'Abuja',
#  'aabiinssy': 'Abyssinia',
#  'aabiinnssy': 'Abyssinian',
#  'aaacdi': 'Acadia',
#  'aacclopu': 'Acapulco',
#  'acceenrtu': 'Accenture',
#  'aaccr': 'Accra',
#  'acdeeov': 'Acevedo',
#  'aaacehn': 'Achaean',
#  'abceeh': 'Achebe',
#  'aacehnrr': 'Achernar',
#  'acehnos': 'Acheson',
#  'acehills': 'Achilles',
#  'aaaccgnou': 'Aconcagua',
#  'aacost': 'Acosta',
#  'acilooprs': 'Acropolis',
#  'acrux': 'Acrux',
#  'aacenot': 'Actaeon',
#  'acnot': 'canto',
#  'acst': 'scat',
#  'acffu': 'Acuff',
#  'aad': 'Ada',
#  'aadm': 'Adam',
#  'aadms': 'Adams',
#  'aadn': 'Dana',
#  'aaadn': 'Adana',
#  'aadr': 'Adar',
#  'aaddms': 'Saddam',
#  'addeelry': 'Adderley',
#  'addei': 'aided',
#  'addinos': 'Addison',
#  'aadel': 'Adela',
#  'aaddeeil': 'Adelaide',
#  'adeel': 'Adele',
#  'adeeiln': 'aliened',
#  'aden': 'dean',
#  'aadeenru': 'Adenauer',
#  'aaadhr': 'Adhara',
#  'aaddis': 'Adidas',
#  'aacddiknor': 'Adirondack',
#  'aacddiknors': 'Adirondacks',
#  'adikns': 'Adkins',
#  'adelr': 'alder',
#  'adflo': 'Adolf',
#  'adfloo': 'Adolfo',
#  'adhlop': 'Adolph',
#  'adinos': 'Adonis',
#  'adeinoss': 'Adonises',
#  'aadinr': 'Adrian',
#  'aaadinr': 'Adriana',
#  'aacdiirt': 'Adriatic',
#  'adeeinnr': 'Adrienne',
#  'adentv': 'advent',
#  'adeinsttv': 'Adventist',
#  'adenstv': 'advents',
#  'adilv': 'valid',
#  'aaeegn': 'Aegean',
#  'acefilr': 'Aelfric',
#  'aaeens': 'Aeneas',
#  'adeein': 'Aeneid',
#  'aelosu': 'Aeolus',
#  'aefloort': 'Aeroflot',
#  'acehlssuy': 'Aeschylus',
#  'aaceilpssuu': 'Aesculapius',
#  'aeops': 'Aesop',
#  'aafghn': 'afghan',
#  'aaafghinnst': 'Afghanistan',
#  'aafghns': 'afghans',
#  'aacfir': 'Africa',
#  'aacfinr': 'African',
#  'aacfinrs': 'Africans',
#  'aaafiknrs': 'Afrikaans',
#  'aaefiknrr': 'Afrikaner',
#  'aaefiknrrs': 'Afrikaners',
#  'afor': 'fora',
#  'acefimnorrst': 'Afrocentrism',
#  'afors': 'Afros',
#  'aaegmmnno': 'Agamemnon',
#  'aagiss': 'Agassi',
#  'aagissz': 'Agassiz',
#  'aaaght': 'Agatha',
#  'aeggi': 'Aggie',
#  'aaagil': 'Aglaia',
#  'aegns': 'Agnes',
#  'aegnw': 'Agnew',
#  'agin': 'gain',
#  'aagr': 'raga',
#  'aacgilor': 'Agricola',
#  'aagippr': 'Agrippa',
#  'aagiinppr': 'Agrippina',
#  'aagilru': 'Aguilar',
#  'aadgilnou': 'Aguinaldo',
#  'aegirru': 'Aguirre',
#  'aginstu': 'Agustin',
#  'aabh': 'Ahab',
#  'aadhm': 'Ahmad',
#  'aaaabddhm': 'Ahmadabad',
#  'aaaddehijmn': 'Ahmadinejad',
#  'adehm': 'Ahmed',
#  'aahimnr': 'Ahriman',
#  'aadi': 'Aida',
#  'aeikn': 'Aiken',
#  'aeeiln': 'Elaine',
#  'aeeim': 'Aimee',
#  'ainu': 'Ainu',
#  'aadeeilr': 'Airedale',
#  'aadeeilrs': 'Airedales',
#  'aahis': 'Aisha',
#  'aajx': 'Ajax',
#  'aabkr': 'Akbar',
#  'aaahkmotv': 'Akhmatova',
#  'ahiikot': 'Akihito',
#  'aaikt': 'Akita',
#  'aaikv': 'Akiva',
#  'aadkk': 'Akkad',
#  'aknor': 'Koran',
#  'aal': 'Ala',
#  'aaaablm': 'Alabama',
#  'aaaablmn': 'Alabaman',
#  'aaaablmns': 'Alabamans',
#  'aaaabilmn': 'Alabamian',
#  'aaaabilmns': 'Alabamians',
#  'aaddiln': 'Aladdin',
#  'aalmo': 'Alamo',
#  'aadglmooor': 'Alamogordo',
#  'aaln': 'anal',
#  'aaaln': 'Alana',
#  'aalr': 'Lara',
#  'aacilr': 'racial',
#  'aaakls': 'Alaska',
#  'aaaklns': 'Alaskan',
#  'aaaklnss': 'Alaskans',
#  'aabl': 'Baal',
#  'aaabiln': 'Albania',
#  'aaabilnn': 'Albanian',
#  'aaabilnns': 'Albanians',
#  'aablny': 'Albany',
#  'abeel': 'Albee',
#  'abeilor': 'Albireo',
#  'abelrt': 'Albert',
#  'aabelrt': 'Alberta',
#  'abelort': 'Latrobe',
#  'aabegiilnns': 'Albigensian',
#  'abilno': 'albino',
#  'abeelqqruuu': 'Albuquerque',
#  'aaaclrtz': 'Alcatraz',
#  'aceilsst': 'scaliest',
#  'aabcdeiils': 'Alcibiades',
#  'acdilnor': 'ironclad',
#  'aacelmn': 'manacle',
#  'aaclo': 'Alcoa',
#  'aclott': 'Alcott',
#  'acilnu': 'Lucian',
#  'acelnoy': 'Alcyone',
#  'aadln': 'Aldan',
#  'aaabdelnr': 'Aldebaran',
#  'adeln': 'laden',
#  'aadeilmnr': 'Alderamin',
#  'adlo': 'load',
#  'adilnr': 'Aldrin',
#  'acel': 'lace',
#  'aceehilm': 'Aleichem',
#  'aaadejlnr': 'Alejandra',
#  'aadejlnor': 'Alejandro',
#  'abeelmrt': 'Alembert',
#  'aelopp': 'Aleppo',
#  'aeltu': 'Aleut',
#  'aaeilntu': 'Aleutian',
#  'aelx': 'axle',
#  'aadeelnrx': 'Alexander',
#  'aaadelnrx': 'Alexandra',
#  'aaadeilnrx': 'Alexandria',
#  'aeeilx': 'Alexei',
#  'aeilsx': 'Alexis',
#  'aflnoos': 'Alfonso',
#  'aflnooz': 'Alfonzo',
#  'adflor': 'Alford',
#  'adeflr': 'flared',
#  'aadeflr': 'Alfreda',
#  'adeflor': 'Alfredo',
#  'abegiln': 'Bengali',
#  'aeglr': 'regal',
#  'aaegilr': 'regalia',
#  'aaegilnr': 'Algerian',
#  'aaegilnrs': 'Algerians',
#  'aabegil': 'Algieba',
#  'aegilrs': 'Algiers',
#  'agllo': 'Gallo',
#  'aagilnnoqu': 'Algonquian',
#  'aagilnnoqsu': 'Algonquians',
#  'agilnnoqu': 'Algonquin',
#  'aaabhlmr': 'Alhambra',
#  'aaehln': 'Alhena',
#  'ail': 'ail',
#  'aceil': 'Celia',
#  'aaciil': 'Alicia',
#  'aeghiiilr': 'Alighieri',
#  'aeiln': 'aline',
#  'ahilot': 'Alioth',
#  'aails': 'alias',
#  'aahils': 'Alisha',
#  'ailnos': 'Alison',
#  'aailss': 'assail',
#  'aaiilrst': 'Alistair',
#  'aadikl': 'Alkaid',
#  'aahll': 'Allah',
#  'aaaabdhll': 'Allahabad',
#  'aalln': 'Allan',
#  'aeeeghillns': 'Alleghenies',
#  'aeeghllny': 'Allegheny',
#  'aaegllr': 'Allegra',
#  'aelln': 'Allen',
#  'adeelln': 'Allende',
#  'aellnnotw': 'Allentown',
#  'aeill': 'Lelia',
#  'aillnos': 'Allison',
#  'aaellstt': 'Allstate',
#  'allnosy': 'Allyson',
#  'aalm': 'lama',
#  'aachlm': 'Almach',
#  'aalmty': 'Almaty',
#  'aghilmty': 'almighty',
#  'aadhlmo': 'Almohad',
#  'aadilmorv': 'Almoravid',
#  'aaillmn': 'Manilla',
#  'aaiklnt': 'Alnitak',
#  'alnooz': 'Alonzo',
#  'aelprt': 'Alpert',
#  'aadhlpr': 'Alphard',
#  'aaccehlp': 'Alphecca',
#  'aaehlprtz': 'Alpheratz',
#  'aehlnops': 'Alphonse',
#  'ahlnoops': 'Alphonso',
#  'aeilnp': 'alpine',
#  'alop': 'opal',
#  'alps': 'slap',
#  'aacels': 'Alsace',
#  'aaailnst': 'Alsatian',
#  'alops': 'opals',
#  'alnost': 'talons',
#  'aalt': 'Alta',
#  'aailt': 'Altai',
#  'aacilt': 'Altaic',
#  'aailrt': 'lariat',
#  'aaailmrt': 'Altamira',
#  'aaehlt': 'Althea',
#  'aaillnopt': 'Altiplano',
#  'aalmnt': 'Altman',
#  'adilost': 'Altoids',
#  'alnot': 'tonal',
#  'aadlru': 'Aludra',
#  'aalv': 'lava',
#  'aaadlorv': 'Alvarado',
#  'aaelrvz': 'Alvarez',
#  'aalorv': 'Alvaro',
#  'ailnv': 'anvil',
#  'acely': 'Lacey',
#  'alnosy': 'Alyson',
#  'aalssy': 'Alyssa',
#  'aeehilmrz': 'Alzheimer',
#  'aademsu': 'Amadeus',
#  'aadmo': 'Amado',
#  'aaailm': 'Amalia',
#  'aaadmn': 'Amanda',
#  'aaillmor': 'Amarillo',
#  'aamru': 'Maura',
#  'aaaemrstu': 'Amaterasu',
#  'aaimt': 'Amati',
#  'aamnoz': 'amazon',
#  'aamnosz': 'amazons',
#  'abemr': 'amber',
#  'aaeilm': 'Amelia',
#  'aeehmnopt': 'Amenhotep',
#  'aaaeimnrs': 'Amerasian',
#  'aaceimr': 'America',
#  'aaceimnr': 'Cinerama',
#  'aaaceimnr': 'Americana',
#  'aaceiimmnrs': 'Americanism',
#  'aaceiimmnrss': 'Americanisms',
#  'aaaceiiimnnortz': 'Americanization',
#  'aaaceiiimnnorstz': 'Americanizations',
#  'aaceeiimnrz': 'Americanize',
#  'aacdeeiimnrz': 'Americanized',
#  'aaceeiimnrsz': 'Americanizes',
#  'aacegiiimnnrz': 'Americanizing',
#  'aaceimnrs': 'Americans',
#  'aaceimrs': 'Americas',
#  'adeimnr': 'Amerind',
#  'aadeiimnnr': 'Amerindian',
#  'aadeiimnnrs': 'Amerindians',
#  'adeimnrs': 'Amerinds',
#  'aaelmns': 'Ameslan',
#  'aachimr': 'Amharic',
#  'aehmrst': 'hamster',
#  'aeim': 'Amie',
#  'aagim': 'Amiga',
#  'ahims': 'Amish',
#  'aammn': 'Amman',
#  'acmoo': 'Amoco',
#  'amos': 'Amos',
#  'aamopr': 'Amparo',
#  'aeempr': 'ampere',
#  'aaimrrst': 'Amritsar',
#  'aademmrst': 'Amsterdam',
#  'aakmrt': 'Amtrak',
#  'ademnnsu': 'Amundsen',
#  'amru': 'Amur',
#  'aamwy': 'Amway',
#  'amy': 'yam',
#  'aan': 'Ana',
#  'aaabinpstt': 'Anabaptist',
#  'aabeln': 'Anabel',
#  'aacinn': 'Anacin',
#  'aacennor': 'Anacreon',
#  'aaehimn': 'Anaheim',
#  'aacelnst': 'Analects',
#  'aaainns': 'Ananias',
#  'aaainsz': 'Anasazi',
#  'aaaainsst': 'Anastasia',
#  'aaelnot': 'Anatole',
#  'aaailnot': 'Anatolia',
#  'aaailnnot': 'Anatolian',
#  'aaaagnorsx': 'Anaxagoras',
#  'aaceghnor': 'anchorage',
#  'aaadilnsu': 'Andalusia',
#  'aaadilnnsu': 'Andalusian',
#  'aaadmnn': 'Andaman',
#  'aadenn': 'Deanna',
#  'adeennrs': 'ensnared',
#  'adennors': 'Anderson',
#  'adens': 'sedan',
#  'aadnorr': 'Andorra',
#  'adenr': 'Nader',
#  'aadenr': 'Andrea',
#  'adeinr': 'rained',
#  'adenrs': 'snared',
#  'adeinrtt': 'nitrated',
#  'adenrw': 'warned',
#  'adenrsw': 'wardens',
#  'addinor': 'android',
#  'aacdehmnor': 'Andromache',
#  'aaddemnor': 'Andromeda',
#  'adnooprv': 'Andropov',
#  'adny': 'Andy',
#  'aaagnr': 'Angara',
#  'aegln': 'glean',
#  'aaegln': 'galena',
#  'aaegiln': 'Angelia',
#  'aacegiln': 'Angelica',
#  'acegilno': 'Angelico',
#  'aaegilnn': 'Angelina',
#  'aeegilnn': 'Angeline',
#  'aeegilnqu': 'Angelique',
#  'aaegilnt': 'Angelita',
#  'aeglno': 'Angelo',
#  'aeglnou': 'Angelou',
#  'aeginnv': 'Angevin',
#  'aegin': 'Angie',
#  'agknor': 'Angkor',
#  'aagiln': 'Anglia',
#  'aacgilnn': 'Anglican',
#  'aacgiilmnns': 'Anglicanism',
#  'aacgiilmnnss': 'Anglicanisms',
#  'aacgilnns': 'Anglicans',
#  'acegiilnz': 'Anglicize',
#  'aglno': 'along',
#  'aeghillnop': 'Anglophile',
#  'aaglno': 'analog',
#  'aaglnno': 'Angolan',
#  'aaglnnos': 'Angolans',
#  'aagnor': 'angora',
#  'aagnors': 'angoras',
#  'aagillnu': 'Anguilla',
#  'agnsu': 'Angus',
#  'aaachikkn': 'Aniakchak',
#  'aabiln': 'Anibal',
#  'aaint': 'Tania',
#  'aaaknr': 'Ankara',
#  'ann': 'Nan',
#  'aann': 'Anna',
#  'aabelnn': 'Annabel',
#  'aabeellnn': 'Annabelle',
#  'aamnn': 'manna',
#  'aailnnops': 'Annapolis',
#  'aaannnpru': 'Annapurna',
#  'aenn': 'Anne',
#  'aeenntt': 'Nanette',
#  'aeinn': 'inane',
#  'aaeimnnr': 'Marianne',
#  'ahilnou': 'Anouilh',
#  'aelmns': 'Anselm',
#  'aelmnos': 'Anselmo',
#  'aahnns': 'Shanna',
#  'aaenstu': 'Antaeus',
#  'aaaainnnortv': 'Antananarivo',
#  'aaccinrtt': 'antarctic',
#  'aaaccinrtt': 'Antarctica',
#  'aaenrst': 'Antares',
#  'ahnnoty': 'Anthony',
#  'achiinrstt': 'Antichrist',
#  'achiinrsstt': 'Antichrists',
#  'aaeimntt': 'Antietam',
#  'aeginnot': 'negation',
#  'aagintu': 'Antigua',
#  'aeillnst': 'Antilles',
#  'achinot': 'Antioch',
#  'aainpst': 'patinas',
#  'aaaafgnostt': 'Antofagasta',
#  'aeinnot': 'Antoine',
#  'aeeinnottt': 'Antoinette',
#  'annot': 'Anton',
#  'aennot': 'Antone',
#  'aainnot': 'Antonia',
#  'ainnnostu': 'Antoninus',
#  'ainnoot': 'Antonio',
#  'ainnostu': 'Antonius',
#  'annoty': 'Antony',
#  'aanntw': 'Antwan',
#  'aenprtw': 'Antwerp',
#  'abinsu': 'Anubis',
#  'aacnz': 'Nazca',
#  'aacehp': 'Apache',
#  'aacehps': 'Apaches',
#  'aaaacchillop': 'Apalachicola',
#  'aeeinnnps': 'Apennines',
#  'adehioprt': 'atrophied',
#  'aaip': 'Apia',
#  'aachoppry': 'Apocrypha',
#  'aaeiillnopr': 'Apollinaire',
#  'alloop': 'Apollo',
#  'aaillnnoop': 'Apollonian',
#  'alloops': 'Apollos',
#  'aaaachilpp': 'Appalachia',
#  'aaaachilnpp': 'Appalachian',
#  'aaaachilnpps': 'Appalachians',
#  'aaaloopps': 'Appaloosa',
#  'aelpp': 'apple',
#  'adeeelpps': 'Appleseed',
#  'aelnoppt': 'Appleton',
#  'aamooppttx': 'Appomattox',
#  'apr': 'rap',
#  'ailpr': 'April',
#  'ailprs': 'spiral',
#  'aeilpsuu': 'Apuleius',
#  'aaefhqrsu': 'Aquafresh',
#  'aaiqrsuu': 'Aquarius',
#  'aaeiqrssuu': 'Aquariuses',
#  'aailqu': 'Aquila',
#  'aainqsu': 'Aquinas',
#  'ainoqu': 'Aquino',
#  'aaeiinqtu': 'Aquitaine',
#  'aar': 'Ara',
#  'aabr': 'Arab',
#  'aaabir': 'Arabia',
#  'aaabinr': 'Arabian',
#  'aaabinrs': 'Arabians',
#  'aabcir': 'Arabic',
#  'aabrs': 'Basra',
#  'aabry': 'Araby',
#  'aaceilr': 'Araceli',
#  'aaafrt': 'Arafat',
#  'aaaagruy': 'Araguaya',
#  'aaacimr': 'Aramaic',
#  'aacmor': 'Aramco',
#  'aaahopr': 'Arapaho',
#  'aaarrt': 'Ararat',
#  'aaaacinnru': 'Araucanian',
#  'aaakrw': 'Arawak',
#  'aaaaknrw': 'Arawakan',
#  'abinorrt': 'Arbitron',
#  'aaacdir': 'Arcadia',
#  'aaacdinr': 'Arcadian',
#  'aacehnr': 'Archean',
#  'aabcdhilr': 'Archibald',
#  'acehir': 'achier',
#  'acdeehimrs': 'Archimedes',
#  'accirt': 'arctic',
#  'acrrstuu': 'Arcturus',
#  'aaeipqru': 'Arequipa',
#  'aers': 'sera',
#  'aaeginnrt': 'Argentina',
#  'aeeginnrt': 'tangerine',
#  'aaegiinnnrt': 'Argentinian',
#  'aaegiinnnrst': 'Argentinians',
#  'agor': 'Argo',
#  'aagnortu': 'Argonaut',
#  'aegnnor': 'Argonne',
#  'agors': 'Argos',
#  'agrsu': 'sugar',
#  'aadeinr': 'Ariadne',
#  'aaiimnrs': 'Arianism',
#  'aeilr': 'Ariel',
#  'aeirs': 'raise',
#  'aeeirss': 'Arieses',
#  'aioorst': 'Ariosto',
#  'aachirrsstu': 'Aristarchus',
#  'adeiirsst': 'Aristides',
#  'aaehinoprsst': 'Aristophanes',
#  'aaeiilnorstt': 'retaliations',
#  'aeilorstt': 'Aristotle',
#  'airsu': 'Arius',
#  'airz': 'Ariz',
#  'aainorz': 'Arizona',
#  'aainnorz': 'Arizonan',
#  'aainnorsz': 'Arizonans',
#  'aaiinnorz': 'Arizonian',
#  'aaiinnorsz': 'Arizonians',
#  'aajnru': 'Arjuna',
#  'akr': 'ark',
#  'aaaknnrs': 'Arkansan',
#  'aaaknrss': 'Arkansas',
#  'aaeghkklnrs': 'Arkhangelsk',
#  'aghikrrtw': 'Arkwright',
#  'aeelnr': 'leaner',
#  'aeilnr': 'linear',
#  'agilnnort': 'Arlington',
#  'aaddegmnor': 'Armageddon',
#  'aaddegmnors': 'Armageddons',
#  'aaacgmnr': 'Armagnac',
#  'aadmnr': 'Armand',
#  'aadmnor': 'Armando',
#  'aaimnr': 'marina',
#  'aaeimnr': 'Armenia',
#  'aaeimnnrs': 'Armenians',
#  'aiimnrsu': 'Arminius',
#  'akmnor': 'Armonk',
#  'amorru': 'Armour',
#  'agmnorrst': 'Armstrong',
#  'aehmnr': 'Herman',
#  'anor': 'roan',
#  'adlnor': 'Ronald',
#  'aflnoru': 'Arnulfo',
#  'aehinrrsu': 'Arrhenius',
#  'anorr': 'Arron',
#  'art': 'tar',
#  'aaeerrstxx': 'Artaxerxes',
#  'aeimrst': 'maestri',
#  'ahrrtu': 'Arthur',
#  'aahinrrtu': 'Arthurian',
#  'aeirt': 'irate',
#  'aorrtu': 'Arturo',
#  'aabru': 'Aruba',
#  'aanry': 'Aryan',
#  'aanrsy': 'Aryans',
#  'aaams': 'Asama',
#  'aacells': 'Ascella',
#  'aadgrs': 'Asgard',
#  'aahinst': 'Tanisha',
#  'acfhorst': 'Ashcroft',
#  'aehs': 'Shea',
#  'aaaghiks': 'Ashikaga',
#  'aaehikmnsz': 'Ashkenazim',
#  'aaabdhhks': 'Ashkhabad',
#  'aeehls': 'Ashlee',
#  'aehlsy': 'Halsey',
#  'aaehlmnos': 'Ashmolean',
#  'aaabhilnprsu': 'Ashurbanipal',
#  'aais': 'Asia',
#  'aains': 'Asian',
#  'aainss': 'Asians',
#  'aaciist': 'Asiatic',
#  'aaciisst': 'Asiatics',
#  'aimosv': 'Asimov',
#  'aaamrs': 'Samara',
#  'aakos': 'Osaka',
#  'aellps': 'lapels',
#  'aenps': 'panes',
#  'adeiikpss': 'Aspidiske',
#  'ahiqstu': 'Asquith',
#  'aadss': 'Assad',
#  'aamss': 'amass',
#  'aaeemsss': 'Assamese',
#  'aiisss': 'Assisi',
#  'aairssy': 'Assyria',
#  'aainrssy': 'Assyrian',
#  'aainrsssy': 'Assyrians',
#  'aaeirst': 'Astaire',
#  'aaanst': 'Astana',
#  'aaerstt': 'Astarte',
#  'anost': 'Aston',
#  'aorst': 'taros',
#  'aaiorst': 'Astoria',
#  'aaahknrst': 'astrakhan',
#  'aforrsttu': 'AstroTurf',
#  'aairsstu': 'Asturias',
#  'aansw': 'Aswan',
#  'aaaacmt': 'Atacama',
#  'aaaahlptu': 'Atahualpa',
#  'aaaalntt': 'Atalanta',
#  'aairt': 'tiara',
#  'aaaabchst': 'Athabasca',
#  'aaaabchnst': 'Athabascan',
#  'aaehnt': 'Athena',
#  'aaehinnt': 'Athenian',
#  'aaehinnst': 'Athenians',
#  'aehnst': 'hasten',
#  'aiknst': 'Atkins',
#  'aiknnost': 'Atkinson',
#  'aaalntt': 'Atlanta',
#  'aaelnstt': 'Atlantes',
#  'aacilntt': 'Atlantic',
#  'aailnstt': 'Atlantis',
#  'aalst': 'atlas',
#  'aaelsst': 'atlases',
#  'aamnt': 'Atman',
#  'aerstu': 'Seurat',
#  'aooprst': 'Atropos',
#  'ast': 'sat',
#  'acitt': 'tacit',
#  'aacitt': 'Attica',
#  'aailtt': 'Attila',
#  'aeeltt': 'Attlee',
#  'acksttu': 'Attucks',
#  'adootw': 'Atwood',
#  'aberuy': 'Aubrey',
#  'aacdklnu': 'Auckland',
#  'adenu': 'Duane',
#  'adiu': 'Audi',
#  'adinou': 'Audion',
#  'aadru': 'Audra',
#  'aderuy': 'Audrey',
#  'abdnouu': 'Audubon',
#  'agu': 'Aug',
#  'aaegnu': 'Augean',
#  'abggrsuu': 'Augsburg',
#  'agstuu': 'august',
#  'aagstuu': 'Augusta',
#  'aagnstuu': 'Augustan',
#  'aeginstuu': 'Augustine',
#  'agsstuu': 'Augusts',
#  'agsstuuu': 'Augustus',
#  'aabegnruz': 'Aurangzeb',
#  'aaeilru': 'Aurelia',
#  'aeiloru': 'Aurelio',
#  'aeilrsuu': 'Aurelius',
#  'aceimnoruy': 'Aureomycin',
#  'aagiru': 'Auriga',
#  'aaorru': 'Aurora',
#  'achistuwz': 'Auschwitz',
#  'aeissu': 'Aussie',
#  'aeisssu': 'Aussies',
#  'aenstu': 'unseat',
#  'aeilrsttuz': 'Austerlitz',
#  'ainstu': 'Unitas',
#  'ainsstu': 'sustain',
#  'aaaailrsstu': 'Australasia',
#  'aaailrstu': 'Australia',
#  'aaailnrstu': 'Saturnalia',
#  'aaailnrsstu': 'Australians',
#  'aadilorstu': 'Australoid',
#  'aacehiloprssttuu': 'Australopithecus',
#  'aairstu': 'Austria',
#  'aainrstu': 'Austrian',
#  'aainrsstu': 'Austrians',
#  'aaeinnorsstu': 'Austronesian',
#  'amntuu': 'autumn',
#  'aav': 'Ava',
#  'aalnov': 'Avalon',
#  'aev': 'Eva',
#  'aeeinntv': 'Venetian',
#  'aenrsuv': 'Avernus',
#  'aeeorrsv': 'Averroes',
#  'aervy': 'Avery',
#  'aaestv': 'Avesta',
#  'aaceinnv': 'Avicenna',
#  'aginnov': 'Avignon',
#  'aailv': 'avail',
#  'aiorv': 'Avior',
#  'aisv': 'visa',
#  'aadgoorv': 'Avogadro',
#  'anov': 'nova',
#  'amux': 'Axum',
#  'aaaly': 'Ayala',
#  'aersy': 'years',
#  'aaamry': 'Aymara',
#  'aehirrsy': 'Ayrshire',
#  'aaderuvy': 'Ayurveda',
#  'abdiuyy': 'Ayyubid',
#  'aaanz': 'Azana',
#  'aaainz': 'Azania',
#  'aaelzz': 'Azazel',
#  'aaabeijnrz': 'Azerbaijan',
#  'aaabeiijnrz': 'Azerbaijani',
#  'aeorsz': 'Azores',
#  'aovz': 'Azov',
#  'acetz': 'Aztec',
#  'aacentz': 'Aztecan',
#  'acestz': 'Aztecs',
#  'aalntz': 'Aztlan',
#  'bmw': 'BMW',
#  'aabht': 'Baath',
#  'aabhistt': 'habitats',
#  'aabbr': 'Babar',
#  'aabbbeg': 'Babbage',
#  'abbbitt': 'Babbitt',
#  'abbel': 'babel',
#  'abbels': 'babels',
#  'abbru': 'Babur',
#  'abblnoy': 'Babylon',
#  'aabbilnnoy': 'Babylonian',
#  'abblnosy': 'Babylons',
#  'aabcll': 'Bacall',
#  'aabcdir': 'Bacardi',
#  'aaaabcchiln': 'Bacchanalia',
#  'abcchsu': 'Bacchus',
#  'abch': 'Bach',
#  'abcksu': 'Backus',
#  'abcno': 'bacon',
#  'aabcirt': 'Bactria',
#  'abden': 'Baden',
#  'aabddlns': 'badlands',
#  'abdeeekr': 'Baedeker',
#  'abez': 'Baez',
#  'abffin': 'Baffin',
#  'abeggis': 'Baggies',
#  'aabddgh': 'Baghdad',
#  'abgiou': 'Baguio',
#  'aaabhm': 'Bahama',
#  'aaabhms': 'Bahamas',
#  'aaabhimn': 'Bahamian',
#  'aaabhimns': 'Bahamians',
#  'aabhi': 'Bahia',
#  'aabhinr': 'Bahrain',
#  'aabikl': 'Baikal',
#  'abeily': 'Bailey',
#  'abdir': 'rabid',
#  'abeeiklt': 'Bakelite',
#  'abekr': 'break',
#  'abdeefiklrs': 'Bakersfield',
#  'abku': 'Baku',
#  'abiknnu': 'Bakunin',
#  'aabcehilnn': 'Balanchine',
#  'aablnot': 'Balaton',
#  'aabblo': 'Balboa',
#  'abdelr': 'blared',
#  'abdilnw': 'Baldwin',
#  'aabceilr': 'Balearic',
#  'abfloru': 'Balfour',
#  'abil': 'bail',
#  'abeeilns': 'baseline',
#  'aabkln': 'Balkan',
#  'aabklns': 'Balkans',
#  'aabhhkls': 'Balkhash',
#  'abll': 'ball',
#  'aabdllr': 'Ballard',
#  'aaabhlrtz': 'Balthazar',
#  'abcilt': 'Baltic',
#  'abeilmort': 'Baltimore',
#  'aabchilnstu': 'Baluchistan',
#  'aabclz': 'Balzac',
#  'aabkmo': 'Bamako',
#  'abbim': 'Bambi',
#  'aabchn': 'Banach',
#  'abcfnort': 'Bancroft',
#  'abdgnnu': 'Bandung',
#  'aabeglnor': 'Bangalore',
#  'abgkkno': 'Bangkok',
#  'aabdeghlns': 'Bangladesh',
#  'aabdeghilns': 'Bangladeshi',
#  'aabdeghilnss': 'Bangladeshis',
#  'abgnor': 'brogan',
#  'abginu': 'Ubangi',
#  'aaabijmnnrs': 'Banjarmasin',
#  'abjlnu': 'Banjul',
#  'abkns': 'banks',
#  'abeeknnr': 'Bernanke',
#  'abeinnrst': 'bannister',
#  'abginnt': 'Banting',
#  'abntu': 'Bantu',
#  'abnstu': 'Bantus',
#  'abootu': 'Baotou',
#  'abipstt': 'baptist',
#  'abeipstt': 'Baptiste',
#  'abipsstt': 'baptists',
#  'aaabbbrs': 'Barabbas',
#  'aabckr': 'Barack',
#  'aaabbdinr': 'Barbadian',
#  'aaabbdinrs': 'Barbadians',
#  'aabbdors': 'Barbados',
#  'aaabbrr': 'Barbara',
#  'aaabbellrr': 'Barbarella',
#  'aaabborrss': 'Barbarossa',
#  'aabbrry': 'Barbary',
#  'abberr': 'barber',
#  'abbeir': 'babier',
#  'abborru': 'Barbour',
#  'aabbrr': 'Barbra',
#  'aabbdru': 'Barbuda',
#  'aabcelnor': 'Barcelona',
#  'aabclry': 'Barclay',
#  'abdeenr': 'Bardeen',
#  'abenrst': 'banters',
#  'abekrr': 'barker',
#  'abeklry': 'Barkley',
#  'ablorw': 'Barlow',
#  'aaabbnrs': 'Barnabas',
#  'aabbnry': 'Barnaby',
#  'aabdnrr': 'Barnard',
#  'aablnru': 'Barnaul',
#  'abenrs': 'Barnes',
#  'abenrtt': 'Barnett',
#  'abenry': 'nearby',
#  'abmnru': 'Barnum',
#  'aabdor': 'abroad',
#  'abeiimoqrstu': 'Barquisimeto',
#  'abrr': 'Barr',
#  'aaabillnqrru': 'Barranquilla',
#  'aaberrr': 'Barrera',
#  'aberrtt': 'Barrett',
#  'abeirr': 'Barrie',
#  'abnorr': 'Barron',
#  'abrry': 'Barry',
#  'abemorrry': 'Barrymore',
#  'abrt': 'brat',
#  'abhrt': 'Barth',
#  'abdhilort': 'Bartholdi',
#  'abehlmoortw': 'Bartholomew',
#  'abelrttt': 'Bartlett',
#  'abnort': 'Barton',
#  'abchru': 'Baruch',
#  'abhiknorsvy': 'Baryshnikov',
#  'abels': 'sable',
#  'abhos': 'Basho',
#  'abeis': 'Basie',
#  'abils': 'basil',
#  'abeqsu': 'Basque',
#  'abeqssu': 'Basques',
#  'abss': 'bass',
#  'abeeerrsst': 'Basseterre',
#  'abeillst': 'Bastille',
#  'aaabnt': 'Bataan',
#  'abest': 'betas',
#  'aabbehhst': 'Bathsheba',
#  'aabistt': 'Batista',
#  'aabmnt': 'bantam',
#  'abeltt': 'tablet',
#  'abtu': 'tuba',
#  'aabdeeilru': 'Baudelaire',
#  'abdinouu': 'Baudouin',
#  'aberu': 'Bauer',
#  'aabhsuu': 'Bauhaus',
#  'abmu': 'Baum',
#  'aaabirv': 'Bavaria',
#  'aaabinrv': 'Bavarian',
#  'abertx': 'Baxter',
#  'abery': 'Bayer',
#  'abesy': 'Bayes',
#  'aabeinsy': 'Bayesian',
#  'abeuxy': 'Bayeux',
#  'ablory': 'Baylor',
#  'abennoy': 'Bayonne',
#  'abehrtuy': 'Bayreuth',
#  'aabchtwy': 'Baywatch',
#  'abceh': 'beach',
#  'abdeel': 'Beadle',
#  'aben': 'bean',
#  'abder': 'debar',
#  'abdeemorr': 'Beardmore',
#  'abdeelrsy': 'Beardsley',
#  'aabeeinrs': 'Bearnaise',
#  'abeelsy': 'Beasley',
#  'aaabeeilmnt': 'Beatlemania',
#  'abeelst': 'Beatles',
#  'abceeirt': 'Beatrice',
#  'abeirtx': 'Beatrix',
#  'abeirtz': 'Beatriz',
#  'abeu': 'beau',
#  'abefortu': 'Beaufort',
#  'aabeijlosu': 'Beaujolais',
#  'aaabcehimrsu': 'Beaumarchais',
#  'abemnotu': 'Beaumont',
#  'aabdeegrru': 'Beauregard',
#  'abeioruv': 'Beauvoir',
#  'bceehlt': 'Bechtel',
#  'bcek': 'beck',
#  'bceekr': 'Becker',
#  'bceekt': 'Becket',
#  'bceektt': 'Beckett',
#  'bceky': 'Becky',
#  'bceeelqru': 'Becquerel',
#  'bdee': 'Bede',
#  'bdeinou': 'Bedouin',
#  'bdeinosu': 'Bedouins',
#  'bbeee': 'Beebe',
#  'bceeehr': 'Beecher',
#  'abeefinor': 'Beefaroni',
#  'bbbeeeluz': 'Beelzebub',
#  'bbeehmor': 'Beerbohm',
#  'beeehnotv': 'Beethoven',
#  'beenot': 'Beeton',
#  'begin': 'binge',
#  'abehn': 'Behan',
#  'beghinr': 'Behring',
#  'bbcdeeeeikr': 'Beiderbecke',
#  'begiijn': 'Beijing',
#  'beirtu': 'Beirut',
#  'beeksy': 'Bekesy',
#  'abelrsu': 'Belarus',
#  'abelu': 'Belau',
#  'beelm': 'Belem',
#  'abeflst': 'Belfast',
#  'abegilns': 'Belgians',
#  'begilmu': 'Belgium',
#  'abdeeglr': 'Belgrade',
#  'abdeiln': 'Belinda',
#  'beeilz': 'Belize',
#  'bell': 'bell',
#  'abell': 'label',
#  'abellmy': 'Bellamy',
#  'abeillrtx': 'Bellatrix',
#  'beeekll': 'Belleek',
#  'beiilln': 'Bellini',
#  'bellow': 'bellow',
#  'belmnot': 'Belmont',
#  'abelmnop': 'Belmopan',
#  'aabehlrszz': 'Belshazzar',
#  'abeelnt': 'tenable',
#  'behilsu': 'Belushi',
#  'ben': 'Ben',
#  'aabceefnrr': 'Benacerraf',
#  'abeenrs': 'Benares',
#  'bceehlny': 'Benchley',
#  'bdeenr': 'bender',
#  'bdeinx': 'Bendix',
#  'bcdeeint': 'Benedict',
#  'bcdeeeiinnt': 'Benedictine',
#  'beelnux': 'Benelux',
#  'beent': 'Benet',
#  'beennott': 'Benetton',
#  'abegln': 'bangle',
#  'abeghinz': 'Benghazi',
#  'beinn': 'Benin',
#  'abeint': 'Benita',
#  'beinot': 'Benito',
#  'abeijmnn': 'Benjamin',
#  'beenntt': 'Bennett',
#  'beeinn': 'Bennie',
#  'benny': 'Benny',
#  'bennos': 'Benson',
#  'abehmnt': 'Bentham',
#  'beelnty': 'Bentley',
#  'bennot': 'bonnet',
#  'benz': 'Benz',
#  'bdeeeinnrz': 'Benzedrine',
#  'beflouw': 'Beowulf',
#  'bbeerr': 'Berber',
#  'bbeerrs': 'Berbers',
#  'bceeeinr': 'Berenice',
#  'abeertt': 'abetter',
#  'begr': 'berg',
#  'beegnr': 'Bergen',
#  'beegrr': 'Gerber',
#  'abceegrr': 'Bergerac',
#  'abegmnr': 'Bergman',
#  'begnors': 'Bergson',
#  'abeir': 'Beria',
#  'beginr': 'Bering',
#  'beeeklry': 'Berkeley',
#  'beehikrrs': 'Berkshire',
#  'beehikrrss': 'Berkshires',
#  'beelr': 'rebel',
#  'beilnr': 'Berlin',
#  'beeilnrr': 'Berliner',
#  'beilnrs': 'Berlins',
#  'beilorz': 'Berlioz',
#  'beilrtz': 'Berlitz',
#  'abdemru': 'rumbaed',
#  'abdemrsu': 'Bermudas',
#  'benr': 'Bern',
#  'abdeeenrtt': 'Bernadette',
#  'abdeeinnr': 'Bernadine',
#  'abdenrr': 'Bernard',
#  'abdenorr': 'Bernardo',
#  'abenrsy': 'Bernays',
#  'abbcehnr': 'Bernbach',
#  'beenr': 'Berne',
#  'abdehnrrt': 'Bernhardt',
#  ...}

# %%
def binary_search(mylist, myitem):
    length = len(mylist)
    if length == 0 or mylist[0] > myitem:
        pass
    else:
        if mylist[(length)//2] == myitem:
            return True
        elif mylist[(length)//2] < myitem:
            return binary_search(mylist[(length)//2 +1:],myitem)
        elif mylist[(length)//2] > myitem:
            return binary_search(mylist[0:((length)//2)],myitem)
    return False

# %%
def find_words(given_words):
    if binary_search(list_for_search, sortbox(given_words)) == True:
        return dic2[sortbox(given_words)]
    else:
        print('None')

# %%
find_words('aibeeln')
# Out:
# None

# %%
binary_search(list_for_search, sortbox('aabehnrty'))
# Out:
# False
